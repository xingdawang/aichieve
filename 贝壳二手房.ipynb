# %%
import requests, time
from bs4 import BeautifulSoup
import pandas as pd


house_information = {
    'house_title': [], # 房屋标题
    'total_price': [], # 房屋总价
    'total_price_unit': [], # 房价
    'unit_price': [], # 单价
    'unit_price_unit': [], # 单价单位
    'community_name': [], # 小区名称
    'administrative_region': [], # 行政区
    'area_name': [], # 区域名称
    'house_type': [], # 房屋户型
    'house_floor': [], # 所在楼层
    'house_area': [], # 建筑面积
    'house_structure': [], # 户型结构
    'construction_type': [], # 建筑类型
    'house_direction': [], # 房屋朝向
    'construction_structure': [], # 建筑结构
    'decoration_status': [], # 装修情况
    'elevator_house_ratio': [], # 梯户比例
    'elevator_status': [], # 配备电梯
    'listing_time': [], # 挂牌时间
    'transaction_rights': [], # 交易权属
    'last_transaction_time': [], # 上次交易
    'house_purpose': [], # 房屋用途
    'house_year_limit': [], # 房屋年限
    'belongings': [], # 产权所属
    'mortgage_status': [], # 抵押信息
    'house_backup': [], # 房本备件
    'house_type_distribution': [], # 户型分布
    'longitude': [],
    'latitude': [],
    'subway': [],
    'subway_distance': [],
    'bus': [],
    'bus_distance': [],
    'kindergarten': [],
    'kindergarten_distance': [],
    'primary_school': [],
    'primary_school_distance': [],
    'middle_school': [],
    'middle_school_distance': [],
    'university': [],
    'university_distance': [],
    'hospital': [],
    'hospital_distance': [],
    'pharmacy': [],
    'pharmacy_distance': [],
    'shop': [],
    'shop_distance': [],
    'supermarket': [],
    'supermarket_distance': [],
    'market': [],
    'market_distance': [],
    'bank': [],
    'bank_distance': [],
    'ATM': [],
    'ATM_distance': [],
    'restaurant': [],
    'restaurant_distance': [],
    'cafe': [],
    'cafe_distance': [],
    'park': [],
    'park_distance': [],
    'cinema': [],
    'cinema_distance': [],
    'fitness_center': [],
    'fitness_center_distance': [],
    'gym': [],
    'gym_distance': [],
    'house_link': [] # 房屋链接
}

dynamic_data = {
    # 经纬度
    'longitude': '',
    'latitude': '',
    # 交通
    'subway': '',
    'subway_distance': '',
    'bus': '',
    'bus_distance': '',
    # 教育
    'kindergarten': '',
    'kindergarten_distance': '',
    'primary_school': '',
    'primary_school_distance': '',
    'middle_school': '',
    'middle_school_distance': '',
    'university': '',
    'university_distance': '',
    # 医疗
    'hospital': '',
    'hospital_distance': '',
    'pharmacy': '',
    'pharmacy_distance': '',
    # 购物
    'shop': '',
    'shop_distance': '',
    'supermarket': '',
    'supermarket_distance': '',
    'market': '',
    'market_distance': '',
    # 生活
    'bank': '',
    'bank_distance': '',
    'ATM': '',
    'ATM_distance': '',
    'restaurant': '',
    'restaurant_distance': '',
    'cafe': '',
    'cafe_distance': '',
    # 娱乐
    'park': '',
    'park_distance': '',
    'cinema': '',
    'cinema_distance': '',
    'fitness_center': '',
    'fitness_center_distance': '',
    'gym': '',
    'gym_distance': '' 
}

columns = ['房屋标题', '房屋总价', '房价单位', '单价', '单价单位', '小区名称', '行政区', '区域名称', '房屋户型', '所在楼层',\
           '建筑面积', '户型结构', '建筑类型', '房屋朝向', '建筑结构', '装修情况', '梯户比例', '配备电梯', '挂牌时间', '交易权属', \
           '上次交易', '房屋用途', '房屋年限', '产权所属', '抵押信息', '房本备件', '户型分布', '经度', '纬度', '地铁站', \
           '距地铁站距离', '汽车站', '距汽车站距离', '幼儿园', '距幼儿园距离', '小学', '距小学距离', '初中', '距初中距离', '大学', \
           '距大学距离', '医院', '距医院距离', '药店', '距药店距离', '商场', '距商场距离', '超市', '距超市距离', \
           '市场', '距市场距离', '银行', '距银行距离', 'ATM', '距ATM距离', '餐厅', '距餐厅距离', '咖啡厅', \
           '距咖啡厅距离','公园', '距公园距离', '电影院', '距电影院距离', '健身房', '距健身房距离', '体院馆', \
           '距体院馆距离', '房屋链接']

dynamic_data_cn = ['经度', '纬度', '地铁站', '距地铁站距离', '汽车站', '距汽车站距离', '幼儿园', '距幼儿园距离', \
                   '小学', '距小学距离', '初中', '距初中距离', '大学', '距大学距离', '医院', '距医院距离', '药店',\
                   '距药店距离', '商场', '距商场距离', '超市', '距超市距离', '市场', '距市场距离', '银行', '距银行距离',\
                   'ATM', '距ATM距离', '餐厅', '距餐厅距离', '咖啡厅', '距咖啡厅距离','公园', '距公园距离', '电影院',\
                   '距电影院距离', '健身房', '距健身房距离', '体院馆', '距体院馆距离']

# %%
def load_amap_dynamic_data(address, city_name, amap_key, dynamic_data = dynamic_data):
    
    # get geo location (latitude, longitude)
    url = 'http://restapi.amap.com/v3/geocode/geo?key=' + amap_key + '&address=' + address + '&city=' + city_name
    page = requests.get(url)
    geo_response = page.json()
    location = geo_response['geocodes'][0]['location']

    # assign latitude and longitude
    latitude, longitude = location.split(',')
    dynamic_data['latitude'] = latitude
    dynamic_data['longitude'] = longitude

    key_word_list = ['地铁', '公交', '幼儿园', '小学', '初中', '大学', \
                     '医院', '药店', '商场', '超市', '市场', '银行', 'ATM', \
                     '餐厅', '咖啡馆', '公园', '电影院', '健身房', '体院馆']

    key_word_index = 0

    dynamic_data_keys = dynamic_data.keys()
    for dynamic_data_key in list(dynamic_data_keys)[2::2]:

        # assemble request url
        url = 'http://restapi.amap.com/v3/place/around?key=' + amap_key + '&location=' + location + '&keywords=' + key_word_list[key_word_index] + '&types=&offset=&page=&extensions=all'
        field_page = requests.get(url)
        place_response = field_page.json()
        name = place_response['pois'][0]['name']
        distance = place_response['pois'][0]['distance']
        key_word_index += 1

        dynamic_data[dynamic_data_key] = name
        dynamic_data[dynamic_data_key + '_distance'] = distance
    
    return dynamic_data

# %%
def load_pages(url, city_name, amap_key, dynamic_data = dynamic_data, load_dynamic = True, verbose = 0):
    
    headers = {'User-Agent': 'Mozilla/5.0'}

    # load page from url
    page = requests.get(url, headers = headers)
    soup = BeautifulSoup(page.text, 'html.parser')
    # url index
    url_index = 1

    # iterate house landing page lists
    house_list = soup.find('ul', class_='sellListContent')

    # get each panel of house page
    houses = house_list.find_all('li', {'class': 'clear'})

    # iterate house panel to extract name and link
    for house in houses:

        # house title
        house_title_section = house.find('div', class_='title')
        house_title = house_title_section.find('a', class_='VIEWDATA').getText().strip()
        house_information['house_title'].append(house_title)

        # house link
        house_link = house_title_section.find('a', class_='VIEWDATA').get('href')
        house_information['house_link'].append(house_link)

        """
        ENTER THE PAGE FROM HERE
        """
        # open house link to get more information:
        house_page = requests.get(house_link, headers = headers)
        house_soup = BeautifulSoup(house_page.text, 'html.parser')


        # Price Section
        price_section = house_soup.find('div', class_='price')

        # get total price
        total_price = price_section.find('span', class_='total').getText().strip()
        house_information['total_price'].append(total_price)

        # get total price unit
        total_price_unit = price_section.find('span', class_='unit').getText().strip()
        house_information['total_price_unit'].append(total_price_unit)

        # get unit price
        unit_price = price_section.find('span', class_='unitPriceValue').getText().strip()
        house_information['unit_price'].append(unit_price)

        # get unit price unit
        unit_price_unit = price_section.find('i').getText().strip()
        house_information['unit_price_unit'].append(unit_price_unit)


        # Community Section
        community_section = house_soup.find('div', class_='communityName')
        community_name = community_section.find('a', class_='info').getText().strip()
        house_information['community_name'].append(community_name)


        # Area Section
        area_section = house_soup.find('div', class_='areaName')
        area_name_info = area_section.find('span', class_='info')
        area_names = area_name_info.find_all('a')

        # get administrative region
        administrative_region = area_names[0].getText().strip()
        house_information['administrative_region'].append(administrative_region)

        # get area name
        area_name = area_names[1].getText().strip()
        house_information['area_name'].append(area_name)

        # Intro Content Seciton
        intro_content_section = house_soup.find('div', class_='introContent')

        # base content section 
        base_section = intro_content_section.find_all('ul')[0]

        # Save information into house_information
        base_section_list = base_section.find_all('li')
        base_index = 0

        # 房屋户型
        if base_section_list[base_index].find('span').getText() == '房屋户型':
            house_type = base_section_list[base_index].find('span').next_sibling.strip()
            base_index += 1
        else:
            house_type = ''
            base_index += 2
        house_information['house_type'].append(house_type)
        # 所在楼层
        if len(base_section_list) > base_index and base_section_list[base_index].find('span').getText() == '所在楼层':
            house_floor = base_section_list[base_index].find('span').next_sibling.strip()
            base_index += 1
        else:
            house_floor = ''
            base_index += 2
        house_information['house_floor'].append(house_floor)
        # 建筑面积
        if len(base_section_list) > base_index and base_section_list[base_index].find('span').getText() == '建筑面积':
            house_area = base_section_list[base_index].find('span').next_sibling.strip()
            base_index += 1
        else:
            house_area = ''
            base_index += 2
        house_information['house_area'].append(house_area)
        # 户型结构
        if len(base_section_list) > base_index and base_section_list[base_index].find('span').getText() == '户型结构':
            house_structure = base_section_list[base_index].find('span').next_sibling.strip()
            base_index += 1
        else:
            house_structure = ''
            base_index += 2
        house_information['house_structure'].append(house_structure)
        # 建筑类型
        if len(base_section_list) > base_index and base_section_list[base_index].find('span').getText() == '建筑类型':
            construction_type = base_section_list[base_index].find('span').next_sibling.strip()
            base_index += 1
        else:
            construction_type = ''
            base_index += 2
        house_information['construction_type'].append(construction_type)
        # 房屋朝向
        if len(base_section_list) > base_index and base_section_list[base_index].find('span').getText() == '房屋朝向':
            house_direction = base_section_list[base_index].find('span').next_sibling.strip()
            base_index += 1
        else:
            house_direction = ''
            base_index += 2
        house_information['house_direction'].append(house_direction)
        # 建筑结构
        if len(base_section_list) > base_index and base_section_list[base_index].find('span').getText() == '建筑结构':
            construction_structure = base_section_list[base_index].find('span').next_sibling.strip()
            base_index += 1
        else:
            construction_structure = ''
            base_index += 2
        house_information['construction_structure'].append(construction_structure)
        # 装修情况
        if len(base_section_list) > base_index and base_section_list[base_index].find('span').getText() == '装修情况':
            decoration_status = base_section_list[base_index].find('span').next_sibling.strip()
            base_index += 1
        else:
            decoration_status = ''
            base_index += 2
        house_information['decoration_status'].append(decoration_status)
        # 梯户比例
        if len(base_section_list) > base_index and base_section_list[base_index].find('span').getText() == '梯户比例':
            elevator_house_ratio = base_section_list[base_index].find('span').next_sibling.strip()
            base_index += 1
        else:
            elevator_house_ratio = ''
            base_index += 2
        house_information['elevator_house_ratio'].append(elevator_house_ratio)
        # 配备电梯
        if len(base_section_list) > base_index and base_section_list[base_index].find('span').getText() == '配备电梯':
            elevator_status = base_section_list[base_index].find('span').next_sibling.strip()
            base_index += 1
        else:
            elevator_status = ''
            base_index += 2
        house_information['elevator_status'].append(elevator_status)

        # transaction section
        transaction_section = intro_content_section.find_all('ul')[1]

        # Extract the information into list
        transaction_section_list = transaction_section.find_all('li')
        # 挂牌时间
        if transaction_section_list[0].find('span').getText() == '挂牌时间':
            listing_time = transaction_section_list[0].find('span').next_sibling.strip()
        else:
            listing_time = ''
        house_information['listing_time'].append(listing_time)
        # 交易权属
        if transaction_section_list[1].find('span').getText() == '交易权属':
            transaction_rights = transaction_section_list[1].find('span').next_sibling.strip()
        else:
            transaction_rights = ''
        house_information['transaction_rights'].append(transaction_rights)
        # 上次交易
        if transaction_section_list[2].find('span').getText() == '上次交易':
            last_transaction_time = transaction_section_list[2].find('span').next_sibling.strip()
        else:
            last_transaction_time = ''
        house_information['last_transaction_time'].append(last_transaction_time)
        # 房屋用途
        if transaction_section_list[3].find('span').getText() == '房屋用途':
            house_purpose = transaction_section_list[3].find('span').next_sibling.strip()
        else:
            house_purpose = ''
        house_information['house_purpose'].append(house_purpose)
        # 房屋年限
        if transaction_section_list[4].find('span').getText() == '房屋年限':
            house_year_limit = transaction_section_list[4].find('span').next_sibling.strip()
        else:
            house_year_limit = ''
        house_information['house_year_limit'].append(house_year_limit)
        # 产权所属
        if transaction_section_list[5].find('span').getText() == '产权所属': 
            belongings = transaction_section_list[5].find('span').next_sibling.strip()
        else:
            belongings = ''
        house_information['belongings'].append(belongings)
        # 抵押信息
        if transaction_section_list[6].find('span').getText() == '抵押信息':
            mortgage_status = transaction_section_list[6].find_all('span')[-1].getText()
        else:
            mortgage_status = ''
        house_information['mortgage_status'].append(mortgage_status)
        # 房本备件
        if transaction_section_list[7].find('span').getText() == '房本备件':
            house_backup = transaction_section_list[7].find('span').next_sibling.strip()
        else:
            house_backup = ''
        house_information['house_backup'].append(house_backup)

        # 户型分布
        house_type_distribution_section = house_soup.find('div', class_='des')
        house_type_distribution = []
        if house_type_distribution_section is not None:
            rows = house_type_distribution_section.find_all('div', class_='row')
            
            for row in rows:
                nodes = row.find_all('div', class_='col')
                content = ''
                for node in nodes:
                    text = node.getText().strip()
                    content += (text + '|')
                house_type_distribution.append(content)
        house_information['house_type_distribution'].append(house_type_distribution)

        if verbose >= 1:
            print(url_index, house_title, house_link)
        url_index += 1

        
        if load_dynamic:
            start_time = time.time()
            address = administrative_region + ' ' + community_name + ' ' + area_name
            dynamic_data = load_amap_dynamic_data(address, city_name, amap_key)
            end_time = time.time()
            if verbose >= 2:
                print('dynamic data takes:', end_time - start_time)

        for key in dynamic_data.keys():
            house_information[key].append(dynamic_data[key])


    return house_information

# %% [markdown]
# ### Single thread

# %%
def single_thread(city_name, amap_key, city_code, excel_name, total_page = 100, get_dynamic_information = True, verbose = 1):

    # initial house_information and dynamic_data
    for key in house_information.keys():
        house_information[key] = []
    for key in dynamic_data.keys():
        dynamic_data[key] = []

    for i in range(1, total_page + 1):

        print('Page:', i)
        start_time = time.time()
        url = 'https://' + city_code + '.ke.com/ershoufang/pg' + str(i)
        print(url)
        load_pages(url, city_name, amap_key, dynamic_data, get_dynamic_information, verbose)
        end_time = time.time()
        print('Page %d takes: %f' % (i, end_time-start_time))


    # convert dictionary into pandas data frame
    houses = pd.DataFrame.from_dict(house_information)
    houses.columns = columns
    houses.to_excel(excel_name, index=False)

# %%
city_name = '上海'
city_code = 'sh'
excel_name = city_name + '.xlsx'
amap_key = 'd7d06348caccd6b66b68be8e2054f778'
get_dynamic_information = False
# verbose = 0: display nothing; verbose = 1: display title & url; verbose = 2: display title & url and dynamic data cost time.
verbose = 1
total_page = 100


single_thread(city_name, amap_key, city_code, excel_name, total_page = total_page, get_dynamic_information = get_dynamic_information, verbose = verbose)

# %%
from pathlib import Path

def single_thread_nearly_all(city_name, amap_key, city_code, excel_name, get_dynamic_information = True, verbose = 1):

#     # initial house_information and dynamic_data
#     for key in house_information.keys():
#         house_information[key] = []
#     for key in dynamic_data.keys():
#         dynamic_data[key] = []

    
    headers = {'User-Agent': 'Mozilla/5.0'}
    total_index = 1

    # load page from url
    page = requests.get('https://' + city_code + '.ke.com/ershoufang/', headers = headers)
    soup = BeautifulSoup(page.text, 'html.parser')

    # iterate house landing page lists
    house_list = soup.find('div', {'data-role': 'ershoufang'})

    # get all the area links
    area_links = []
    area_links_section = house_list.find_all('a', {'class': 'CLICKDATA'})
    for area_link in area_links_section:
        area_links.append(area_link.get('href').split('/')[-2])

    for area_link in area_links:
        
        current_file = Path(area_link + '_' + excel_name)

        if not current_file.is_file():

            # initial house_information and dynamic_data
            for key in house_information.keys():
                house_information[key] = []
            for key in dynamic_data.keys():
                dynamic_data[key] = []

            # get total pages
            area_page = requests.get('https://' + city_code + '.ke.com/ershoufang/' + area_link, headers = headers)
            area_soup = BeautifulSoup(area_page.text, 'html.parser')

            total_page_section = area_soup.find('div', {'class':'page-box house-lst-page-box'})
            if total_page_section == None:
                total_page = 0
            else:
                total_page = eval(total_page_section.get('page-data'))['totalPage']
            total_page

            # get each page details
            for i in range(1, total_page + 1):

                print('Area: %s Page: %d Total Record No: %d' % (area_link, i, total_index))
                total_index += 1
                start_time = time.time()
                url = 'https://' + city_code + '.ke.com/ershoufang/' + area_link + '/pg' + str(i)

                load_pages(url, city_name, amap_key, dynamic_data, get_dynamic_information, verbose)
                end_time = time.time()
                print('Page %d takes: %f' % (i, end_time-start_time))


            # convert dictionary into pandas data frame
            houses = pd.DataFrame.from_dict(house_information)
            houses.columns = columns
            houses.to_excel(area_link + '_' + excel_name, index=False)

# %%
city_name = '上海'
city_code = 'sh'
excel_name = city_name + '.xlsx'
amap_key = 'd7d06348caccd6b66b68be8e2054f778'
get_dynamic_information = False
# verbose = 0: display nothing; verbose = 1: display title & url; verbose = 2: display title & url and dynamic data cost time.
verbose = 1


single_thread_nearly_all(city_name, amap_key, city_code, excel_name, get_dynamic_information = get_dynamic_information, verbose = verbose)
# Out:
# Area: qingpu Page: 1 Total Record No: 1
# 1 满五唯一|无抵押无户口|产权清晰|业主急售 https://sh.ke.com/ershoufang/107102846226.html
# 2 春江三月公寓二期 3室2厅 南 https://sh.ke.com/ershoufang/107102845185.html
# 3 春江三月公寓二期 2室1厅 南 https://sh.ke.com/ershoufang/107102845175.html
# 4 青浦城区，全明户型，精装三房，诚意出售，低总价 https://sh.ke.com/ershoufang/107102844399.html
# 5 佳乐苑 3室2厅 南 北 https://sh.ke.com/ershoufang/107102841433.html
# 6 满五唯一，花园洋房，拎包入住带车位，南北通 https://sh.ke.com/ershoufang/107102833209.html
# 7 景观楼层   业主自住保养好，清爽两房 https://sh.ke.com/ershoufang/107102833205.html
# 8 高楼层，两室两厅一厨一卫，两房朝南，视野开阔价格低 https://sh.ke.com/ershoufang/107102830505.html
# 9 桂花园(青浦) 3室1厅 南 https://sh.ke.com/ershoufang/107102829303.html
# 10 满两年，小区四周依水还绕，位置安静，拎包入住 https://sh.ke.com/ershoufang/107102829132.html
# 11 店长推荐，必看好房，动静分明，闹中取静 https://sh.ke.com/ershoufang/107102828993.html
# 12 二房全明户型，一手动迁，随时可签 https://sh.ke.com/ershoufang/107102827631.html
# 13 近地铁，业主诚心出售，南北户型，视野采好 https://sh.ke.com/ershoufang/107102826451.html
# 14 精致社区，优美环境，买两房享受美好人生 https://sh.ke.com/ershoufang/107102825093.html
# 15 眺望佘山  景观楼层  一手动迁无增值税  诚心出售 https://sh.ke.com/ershoufang/107102824098.html
# 16 富力桃园   诚意出售   采光好   视野好 https://sh.ke.com/ershoufang/107102820455.html
# 17 海棠馨苑南区 2室1厅 南 https://sh.ke.com/ershoufang/107102819679.html
# 18 徐泾北城欣沁苑东区 2室2厅 南 北 https://sh.ke.com/ershoufang/107102819484.html
# 19 大虹桥板块|精装带地暖|满两年|高品质三房 https://sh.ke.com/ershoufang/107102817558.html
# 20 近地铁，有阁楼，全明户型，采光好，满两年税少 https://sh.ke.com/ershoufang/107102816381.html
# 21 桂花园(青浦) 3室1厅 南 https://sh.ke.com/ershoufang/107102812362.html
# 22 保安新村 3室2厅 南 北 https://sh.ke.com/ershoufang/107102809005.html
# 23 看不中不要钱的两房户型，南北通全明，南北双阳台 https://sh.ke.com/ershoufang/107102804772.html
# 24 房东诚意出售，高楼层，毓秀、佳佳、地铁950米 https://sh.ke.com/ershoufang/107102804347.html
# 25 民乐佳苑二区 3室2厅 南 https://sh.ke.com/ershoufang/107102802956.html
# 26 满五唯一 南北通  紧俏楼层 好位置 近地铁 随时看 https://sh.ke.com/ershoufang/107102802790.html
# 27 欣乐苑（东苑） 2室1厅 南 https://sh.ke.com/ershoufang/107102801091.html
# 28 五年内装修 中间楼层 一房两厅 诚意出售 https://sh.ke.com/ershoufang/107102800478.html
# 29 旭辉百合宫馆 2室2厅 南 https://sh.ke.com/ershoufang/107102799473.html
# 30 此房满五唯一税费少，户型格局好带阁楼，诚心出售 https://sh.ke.com/ershoufang/107102795294.html
# Page 1 takes: 111.411420
# Area: qingpu Page: 2 Total Record No: 2
# 1 近地铁，南北通户型，通风良好.. https://sh.ke.com/ershoufang/107102794979.html
# 2 近地铁+满五唯一+小区好位置+业主诚售 https://sh.ke.com/ershoufang/107102794766.html
# 3 近地铁、万科物业、房形南北直通、品质小区 https://sh.ke.com/ershoufang/107102793146.html
# 4 高档小区，楼层好，南北通，精装修，空调地暖 https://sh.ke.com/ershoufang/107102792538.html
# 5 民乐佳苑二区 2室1厅 南 https://sh.ke.com/ershoufang/107102791450.html
# 6 胜利路204弄 2室1厅 南 https://sh.ke.com/ershoufang/107102788663.html
# 7 西部花苑（二、六期） 2室2厅 南 https://sh.ke.com/ershoufang/107102785547.html
# 8 上海捷克住宅小区(公寓) 2室2厅 南 https://sh.ke.com/ershoufang/107102784888.html
# 9 欣乐苑（西苑） 2室2厅 南 https://sh.ke.com/ershoufang/107102783717.html
# 10 新城开发商，绿化高，居住环境舒适 https://sh.ke.com/ershoufang/107102782673.html
# 11 精装三房，楼层好视野开阔，交通配套完善 https://sh.ke.com/ershoufang/107102781480.html
# 12 秀景苑精装修三房 南北户型 拎包入住 https://sh.ke.com/ershoufang/107102780300.html
# 13 国展旁，正虹桥，次新小区，带车位，精装自住，保养好 https://sh.ke.com/ershoufang/107102779919.html
# 14 崧泽华城秀景苑(二期) 1室1厅 南 https://sh.ke.com/ershoufang/107102779716.html
# 15 小区中间位置，采光好，前后无遮挡 https://sh.ke.com/ershoufang/107102778926.html
# 16 近宝龙，交通便利，毛坯可自由装修 https://sh.ke.com/ershoufang/107102778157.html
# 17 小区位置好，景观楼层，近地铁千呼万唤始出来的好房 https://sh.ke.com/ershoufang/107102776498.html
# 18 汇金路地铁口900米，带地下租赁车位,采光通风好 https://sh.ke.com/ershoufang/107102775162.html
# 19 这就是你要的高楼层，全明户型通透两房！ https://sh.ke.com/ershoufang/107102774966.html
# 20 欣乐苑中间楼层两房，采光视野无遮挡！！！ https://sh.ke.com/ershoufang/107102773938.html
# 21 一手动迁，满五唯一，税少，大两房中间楼层位置好！ https://sh.ke.com/ershoufang/107102772252.html
# 22 地铁400多米，中间楼层，全明户型，位置安静 https://sh.ke.com/ershoufang/107102772008.html
# 23 近地铁+ 满五唯一+业主诚心卖+楼层佳 https://sh.ke.com/ershoufang/107102771691.html
# 24 春江三月公寓二期 2室1厅 南 https://sh.ke.com/ershoufang/107102769997.html
# 25 唯一在售一房，通风好。户型好。 https://sh.ke.com/ershoufang/107102769014.html
# 26 精装修，户型方正，大三房，小区品质高 https://sh.ke.com/ershoufang/107102768662.html
# 27 西部花苑（二、六期） 3室2厅 南 https://sh.ke.com/ershoufang/107102767728.html
# 28 精装修，南北通飞机户型，满五不唯一 https://sh.ke.com/ershoufang/107102767068.html
# 29 万寿五区，中间楼层，诚意出售，看房提前预约 https://sh.ke.com/ershoufang/107102767042.html
# 30 近地铁满两年，税费少，两房户型正气，南北通采光好 https://sh.ke.com/ershoufang/107102765986.html
# Page 2 takes: 134.021983
# Area: qingpu Page: 3 Total Record No: 3
# 1 绿中海四期中间套小三房，自住装修，诚意出售。 https://sh.ke.com/ershoufang/107102765681.html
# 2 17号地铁欣乐苑中间套，户型好，采光足，诚意出售！ https://sh.ke.com/ershoufang/107102765407.html
# 3 总价低，位置好，千呼万唤始出来的好房 https://sh.ke.com/ershoufang/107102762516.html
# 4 此房楼层优质，通透户型，功能间都带窗。 https://sh.ke.com/ershoufang/107102761838.html
# 5 精装婚房，业主诚心出售，精装商品房，次新房 https://sh.ke.com/ershoufang/107102758474.html
# 6 70平阁楼加10平露台，客厅挑空，小区中间位置3+1房间 https://sh.ke.com/ershoufang/107102757568.html
# 7 次新小区 环境优美 品质小区 双阳台 https://sh.ke.com/ershoufang/107102756870.html
# 8 金地格林郡，花园洋房，拎包入住带车位，绿化好 https://sh.ke.com/ershoufang/107102756357.html
# 9 崧文苑 3室2厅 南 https://sh.ke.com/ershoufang/107102755181.html
# 10 税费少    景观楼层   采光通风俱佳   业主诚意出售 https://sh.ke.com/ershoufang/107102753460.html
# 11 景观楼层，远眺佘山，中上等装修，税少可签，诚意出售 https://sh.ke.com/ershoufang/107102752630.html
# 12 此房带产权车位＋满五唯一+精装3房2卫的户型 https://sh.ke.com/ershoufang/107102751603.html
# 13 中间楼层 满五唯一 三房经济实用  看房随时 https://sh.ke.com/ershoufang/107102751474.html
# 14 精装修，南北通透，采光通风好，拎包入住 https://sh.ke.com/ershoufang/107102751440.html
# 15 正虹桥丨精装大三房丨税费低丨户型方正丨看中可谈 https://sh.ke.com/ershoufang/107102747386.html
# 16 高楼层三开间朝南 方便看房 阳光充沛 https://sh.ke.com/ershoufang/107102745586.html
# 17 崧泽华城逸泰雅苑（二期） 2室2厅 南 https://sh.ke.com/ershoufang/107102745478.html
# 18 大虹桥板块|南北朝向|户型方正|视野开阔 https://sh.ke.com/ershoufang/107102745095.html
# 19 想要有装修的温馨一家 朝南三开间 等你来看 https://sh.ke.com/ershoufang/107102743890.html
# 20 房源为一手动迁房，无增值税，无抵押无贷款， https://sh.ke.com/ershoufang/107102743828.html
# 21 17号线地铁大三房，税费少，得房率高，16年婚房装修 https://sh.ke.com/ershoufang/107102743802.html
# 22 青浦新城站3号口400多米，配套齐全 https://sh.ke.com/ershoufang/107102743236.html
# 23 留水园 2室1厅 南 https://sh.ke.com/ershoufang/107102742015.html
# 24 宜达新居 3室1厅 南 https://sh.ke.com/ershoufang/107102739819.html
# 25 南北通透，采光充足，户型合理。 https://sh.ke.com/ershoufang/107102739759.html
# 26 怡田小区 3室1厅 南 https://sh.ke.com/ershoufang/107102739170.html
# 27 海棠馨苑南区 2室1厅 南 https://sh.ke.com/ershoufang/107102738786.html
# 28 中间楼层，钥匙，业主诚心，看房随时 https://sh.ke.com/ershoufang/107102738728.html
# 29 绿中海明苑(公寓) 3室2厅 南 https://sh.ke.com/ershoufang/107102735774.html
# 30 保安大三房，采光通风俱佳，中间楼层，配套齐全 https://sh.ke.com/ershoufang/107102735750.html
# Page 3 takes: 116.302856
# Area: qingpu Page: 4 Total Record No: 4
# 1 绿中海明苑五期的2+1，精装修，中空调+地暖。 https://sh.ke.com/ershoufang/107102735743.html
# 2 中！央空调+地暖！一梯一户！全新精装修大三房 https://sh.ke.com/ershoufang/107102732938.html
# 3 海棠馨苑南区 3室1厅 南 https://sh.ke.com/ershoufang/107102731726.html
# 4 近地铁 低密度 高品质 洋房社区 配套成熟 https://sh.ke.com/ershoufang/107102730733.html
# 5 开发精装 中间楼层 视野好 户型正 舒适感高 https://sh.ke.com/ershoufang/107102730345.html
# 6 浩泽家园 3室1厅 南 https://sh.ke.com/ershoufang/107102730192.html
# 7 带装修可领包入住，小区安静适宜居住，2014年小区 https://sh.ke.com/ershoufang/107102729543.html
# 8 金瑞苑 北苑 2室1厅 南 https://sh.ke.com/ershoufang/107102729432.html
# 9 新城盛景一楼可做花园，纯毛坯可随意装修 https://sh.ke.com/ershoufang/107102729256.html
# 10 西边套户，全明户型，景观楼层，出行方便，配套齐全。 https://sh.ke.com/ershoufang/107102727804.html
# 11 西边套 南北通 采光好 总价低 随时看 https://sh.ke.com/ershoufang/107102726054.html
# 12 一首动迁次新房无增值税，景观楼层，户型方正 https://sh.ke.com/ershoufang/107102724544.html
# 13 瑞和锦庭-东区 2室1厅 南 https://sh.ke.com/ershoufang/107102723456.html
# 14 欣乐苑高楼层两房，业主诚意出售，等您带价来谈！！ https://sh.ke.com/ershoufang/107102720936.html
# 15 全明两房  中间楼层  户型正气  可拎包入住 https://sh.ke.com/ershoufang/107102719264.html
# 16 全明户型，税费低，品质小区环境好，带地暖 https://sh.ke.com/ershoufang/107102718771.html
# 17 全南户型 高楼层 采光通风无遮挡 原始动迁税少 https://sh.ke.com/ershoufang/107102718396.html
# 18 17号线800米，南北双阳台，楼层好前后无遮挡 https://sh.ke.com/ershoufang/107102716742.html
# 19 近地铁景观楼层，边套，采光好视野开阔房东诚意出售 https://sh.ke.com/ershoufang/107102716727.html
# 20 边套户型+看房方便+南北通风+诚意出售+拐角大窗 https://sh.ke.com/ershoufang/107102715450.html
# 21 春听雨声，夏听蝉声，秋听风声，冬听雪声。 https://sh.ke.com/ershoufang/107102714187.html
# 22 西虹桥壹号 3室2厅 南 https://sh.ke.com/ershoufang/107102714030.html
# 23 你要的带大阁楼 别墅品质小区 户型正南北通透 近地铁 https://sh.ke.com/ershoufang/107102712494.html
# 24 仁恒两房 景观楼层 精装修 带产权车位 户型正气 https://sh.ke.com/ershoufang/107102710241.html
# 25 外滩旁 满五唯一 精装修 正气三开间朝南 全明 https://sh.ke.com/ershoufang/107102709915.html
# 26 地铁口次新房，总价低小面积两房，未住过人随时可看 https://sh.ke.com/ershoufang/107102709843.html
# 27 西虹桥，品质两居，万科物业，带产权车位 https://sh.ke.com/ershoufang/107102709785.html
# 28 锦绣逸庭(公寓) 2室1厅 南 北 https://sh.ke.com/ershoufang/107102709631.html
# 29 春江三月公寓二期 2室2厅 南 https://sh.ke.com/ershoufang/107102708847.html
# 30 众里寻他千百度，蓦然回首，此房就在灯火阑珊处 https://sh.ke.com/ershoufang/107102708102.html
# Page 4 takes: 107.002340
# Area: qingpu Page: 5 Total Record No: 5
# 1 汇金路 地铁  带装修  总价低 https://sh.ke.com/ershoufang/107102707921.html
# 2 业主诚意出售，小区环境好，居住舒适 https://sh.ke.com/ershoufang/107102704497.html
# 3 崧泽华城德康雅苑 3室1厅 南 https://sh.ke.com/ershoufang/107102704125.html
# 4 南北通风 三面采光 北临河 原始动迁税少 https://sh.ke.com/ershoufang/107102701771.html
# 5 满五唯一|精装修|大四房|中间楼层 https://sh.ke.com/ershoufang/107102699654.html
# 6 高楼层，采光好，通风好，诚意出售 https://sh.ke.com/ershoufang/107102698949.html
# 7 御澜湾 3室2厅 南 https://sh.ke.com/ershoufang/107102697983.html
# 8 国展百老汇在侧，双地铁，通达2、10、17号线 https://sh.ke.com/ershoufang/107102694795.html
# 9 附地下产权车位！近吾悦+近轨交+近环线！全新精装修！ https://sh.ke.com/ershoufang/107102693618.html
# 10 高楼层，视野好，采光充足，地铁沿线，一手动迁 https://sh.ke.com/ershoufang/107102691667.html
# 11 晨兴花园大三房，阁楼两居正常居住，地铁1公里 https://sh.ke.com/ershoufang/107102691244.html
# 12 首创在售唯一大户型125平四房 https://sh.ke.com/ershoufang/107102691186.html
# 13 前面无遮挡位置很好，前面一片空地 https://sh.ke.com/ershoufang/107102690003.html
# 14 华骥苑二期大平层三房，满五年唯一，单价低 https://sh.ke.com/ershoufang/107102686986.html
# 15 近地铁，全明户型装修清爽，满五唯一 https://sh.ke.com/ershoufang/107102686873.html
# 16 高楼层，通风好，采光好，看房方便，诚意出售 https://sh.ke.com/ershoufang/107102686199.html
# 17 房间全南 户型通透 配套成熟 生活方便 https://sh.ke.com/ershoufang/107102685187.html
# 18 研究生店长推荐新上好房，业主诚意出售 https://sh.ke.com/ershoufang/107102683635.html
# 19 雅苑 3室2厅 南 https://sh.ke.com/ershoufang/107102681546.html
# 20 高楼层采光好，一手动迁税费低，南北户型 https://sh.ke.com/ershoufang/107102680451.html
# 21 店长推荐 ，精装修，业主诚心出售，税费少 https://sh.ke.com/ershoufang/107102680214.html
# 22 全南户型大平层 厨卫全明 景观楼层 带地下车位 https://sh.ke.com/ershoufang/107102677035.html
# 23 民乐佳苑一区 3室2厅 南 https://sh.ke.com/ershoufang/107102676752.html
# 24 春江三月公寓二期 3室1厅 南 https://sh.ke.com/ershoufang/107102675758.html
# 25 大三房 中间位置 采光好  精装修 https://sh.ke.com/ershoufang/107102673384.html
# 26 玫瑰湾满五唯一，精装楼层佳，价可谈诚售，看房方便 https://sh.ke.com/ershoufang/107102671498.html
# 27 华骥苑非顶楼，户型方正，南北通，全明户型 https://sh.ke.com/ershoufang/107102667800.html
# 28 一手动迁无增值税，眺望佘山，户型方正，业主诚心出售 https://sh.ke.com/ershoufang/107102667755.html
# 29 中间楼层，总价低，2014次新小区税费少 https://sh.ke.com/ershoufang/107102664923.html
# 30 全明格局，南北通风，采光好，干湿分离 https://sh.ke.com/ershoufang/107102664412.html
# Page 5 takes: 111.539680
# Area: qingpu Page: 6 Total Record No: 6
# 1 看房请带上墨镜，不然阳光刺眼，全明三房，南北边套 https://sh.ke.com/ershoufang/107102661010.html
# 2 保安新村 3室2厅 南 https://sh.ke.com/ershoufang/107102660926.html
# 3 源昌幸福里 3室2厅 南 https://sh.ke.com/ershoufang/107102659482.html
# 4 户型好，满五唯一，税费少，出行方便，楼层好，无遮挡 https://sh.ke.com/ershoufang/107102658467.html
# 5 大国展时代，双地铁交通便利，出勤通达2-10-17号线 https://sh.ke.com/ershoufang/107102657036.html
# 6 小区三开间朝南户型，采光无影响 https://sh.ke.com/ershoufang/107102656970.html
# 7 南北格局优秀 一梯两户得房率高 别墅区环境好徐泾产权 https://sh.ke.com/ershoufang/107102655777.html
# 8 精装修~~青浦新城地铁站+全明户型+环境优美+诚心出售 https://sh.ke.com/ershoufang/107102655644.html
# 9 葛洲坝玉兰花园 4室2厅 南 https://sh.ke.com/ershoufang/107102655111.html
# 10 全明南北通两房+无抵押产权清晰+无增值税随时可看 https://sh.ke.com/ershoufang/107102653154.html
# 11 边套两房，楼层好，南北户型一手动迁，税费少！ https://sh.ke.com/ershoufang/107102651205.html
# 12 欣乐苑好楼层中间套，户型好，采光足，诚意出售！ https://sh.ke.com/ershoufang/107102651198.html
# 13 大虹桥花园洋房|户型方正|南北通透|双南两房两卫 https://sh.ke.com/ershoufang/107102651117.html
# 14 中间楼层 装修好 税费少 卖家诚意 https://sh.ke.com/ershoufang/107102649274.html
# 15 外滩河景房 观光漫步皆可  经典全明两房 等你来约 https://sh.ke.com/ershoufang/107102647374.html
# 16 近地铁户型好，全明户型，楼间距宽，采光没有遮挡 https://sh.ke.com/ershoufang/107102644182.html
# 17 小区户型方正，电梯房，房龄新，价格实惠 https://sh.ke.com/ershoufang/107102639906.html
# 18 如果您要找日常生活便捷 温馨一房 看看这个！ https://sh.ke.com/ershoufang/107102638806.html
# 19 近地铁、满五唯一、大三房，装修保养好 https://sh.ke.com/ershoufang/107102636937.html
# 20 满五唯一地铁1000米  品质小区，大虹桥辐射范围 https://sh.ke.com/ershoufang/107102636326.html
# 21 满五年，2011年的次新电梯房，边套两房朝南 https://sh.ke.com/ershoufang/107102635333.html
# 22 朱家角花园洋房 户型方正 诚心出售 https://sh.ke.com/ershoufang/107102634146.html
# 23 南北通透 全明户型 精装修 户型方正 税费少 https://sh.ke.com/ershoufang/107102633614.html
# 24 青浦高档住宅，花园洋房，环境优美 https://sh.ke.com/ershoufang/107102633505.html
# 25 此房源价格合理， 优质中间楼层，通透户型 https://sh.ke.com/ershoufang/107102633480.html
# 26 诚意出售，装修新，家具配套齐全，品质好 https://sh.ke.com/ershoufang/107102631289.html
# 27 楼层好，视野开阔，小外滩景观房，格局好。 https://sh.ke.com/ershoufang/107102631174.html
# 28 精装小两房 毓秀、佳佳幼儿园 中山医院 带电梯 https://sh.ke.com/ershoufang/107102630329.html
# 29 景观楼层、双南户型3室 公园小区人车分流、带车位 https://sh.ke.com/ershoufang/107102628588.html
# 30 中建锦绣天地 2室2厅 南 https://sh.ke.com/ershoufang/107102623992.html
# Page 6 takes: 117.248225
# Area: qingpu Page: 7 Total Record No: 7
# 1 卫生间有窗来了！全明三房精装东边套。房子满五唯一 https://sh.ke.com/ershoufang/107102622736.html
# 2 四房朝南 精装修 带电梯 有钥匙 看房联系维护人 诚售 https://sh.ke.com/ershoufang/107102619831.html
# 3 小区中间位置，三室两厅两卫，顶楼带阁楼 https://sh.ke.com/ershoufang/107102615176.html
# 4 万寿新村(青浦) 3室1厅 南 北 https://sh.ke.com/ershoufang/107102614615.html
# 5 浩泽|精装小3房中等楼层 一手动迁 满五唯一 诚售 https://sh.ke.com/ershoufang/107102614492.html
# 6 低楼层适合老人，户型通透，位置好 https://sh.ke.com/ershoufang/107102614355.html
# 7 瑞和锦庭-东区 2室2厅 南 https://sh.ke.com/ershoufang/107102614250.html
# 8 满五唯一全明户型中间楼层配套齐全 https://sh.ke.com/ershoufang/107102613888.html
# 9 边套南北通两房，看中带价来谈。 https://sh.ke.com/ershoufang/107102613137.html
# 10 河景房，装修保养好，业主诚意出售 https://sh.ke.com/ershoufang/107102608939.html
# 11 店长推荐新上好房，业主诚意出售 https://sh.ke.com/ershoufang/107102606085.html
# 12 瑞和锦庭-东区 2室1厅 东南 https://sh.ke.com/ershoufang/107102604768.html
# 13 瑞和锦庭-西区 2室1厅 南 https://sh.ke.com/ershoufang/107102604235.html
# 14 全屋智能家居，双地铁口，出勤通达2、17、10号线 https://sh.ke.com/ershoufang/107102603834.html
# 15 新城盛景园 3室1厅 南 https://sh.ke.com/ershoufang/107102602223.html
# 16 欧式装修，南北通风，3房2厅2卫，中间楼层，近地铁 https://sh.ke.com/ershoufang/107102601216.html
# 17 户型正气，全明户型，采光好，环境优美。 https://sh.ke.com/ershoufang/107102600822.html
# 18 城东新村一村 2室2厅 南 https://sh.ke.com/ershoufang/107102598522.html
# 19 边套户型，全明户型，景观楼层，出行方便，配套齐全 https://sh.ke.com/ershoufang/107102597113.html
# 20 原始动迁房，免增值税，高楼层，精装修，交通便利 https://sh.ke.com/ershoufang/107102596717.html
# 21 城东新村，靠河大两房，采光、通风好，全明，居住舒适 https://sh.ke.com/ershoufang/107102596244.html
# 22 店长推荐，洋房看景高层。高品质飞机户型精装修 https://sh.ke.com/ershoufang/107102595546.html
# 23 采光和视野较好，看房方便，业主诚意出售 https://sh.ke.com/ershoufang/107102594753.html
# 24 新城开发，地铁17年新小区，户型正气，看房方便 https://sh.ke.com/ershoufang/107102594680.html
# 25 新挂牌仁恒运杰，业主新房买好了，诚意出售随时可看 https://sh.ke.com/ershoufang/107102593059.html
# 26 崧泽华城华中苑 2室2厅 南 https://sh.ke.com/ershoufang/107102591011.html
# 27 诚意出售 方便看房 视野好 附带阁楼 https://sh.ke.com/ershoufang/107102588995.html
# 28 欣乐苑（东苑） 2室2厅 南 https://sh.ke.com/ershoufang/107102585780.html
# 29 地铁口，南北直通， 楼层佳，,配套齐 https://sh.ke.com/ershoufang/107102585083.html
# 30 一手动迁，满五年，税费少，大阁楼，带露台 https://sh.ke.com/ershoufang/107102580115.html
# Page 7 takes: 97.223224
# Area: qingpu Page: 8 Total Record No: 8
# 1 楼层好采光好，户型正气三开间朝南，税费少！！！ https://sh.ke.com/ershoufang/107102579999.html
# 2 装修50万 保养好 精心设计装修材料考究 楼层视野好 https://sh.ke.com/ershoufang/107102579775.html
# 3 高绿化 安静宜居社区 配套完事 绿城品质物业 税费低 https://sh.ke.com/ershoufang/107102575730.html
# 4 采光好 空间宽敞 户型正气 配套齐全 诚意出售 https://sh.ke.com/ershoufang/107102575454.html
# 5 毛坯房，原始户型，从未入住过，景观房，南临河 https://sh.ke.com/ershoufang/107102575345.html
# 6 近地铁，户型好，环境优美，配套设施齐全 https://sh.ke.com/ershoufang/107102575325.html
# 7 金地南北通，业主诚心出售 视野开阔 https://sh.ke.com/ershoufang/107102572041.html
# 8 新城盛景临河 大三房带二十多平花园 https://sh.ke.com/ershoufang/107102571654.html
# 9 海棠馨苑南区 3室1厅 南 https://sh.ke.com/ershoufang/107102571298.html
# 10 精装拎包入住，边套全明户型，视野无遮挡， https://sh.ke.com/ershoufang/107102571200.html
# 11 秀景苑二期简装二房。业主诚意出售 https://sh.ke.com/ershoufang/107102567823.html
# 12 满五唯一 带阁楼 有露台，户型南北通，近地铁 https://sh.ke.com/ershoufang/107102566852.html
# 13 笑傲江湖令狐冲重出江湖欲称霸武林故惜别爱舍有意抛售 https://sh.ke.com/ershoufang/107102565905.html
# 14 商品房，电梯次顶楼，两梯四户，城区高层，视野舒适 https://sh.ke.com/ershoufang/107102565594.html
# 15 新城精装一楼大三房，居住舒适。 https://sh.ke.com/ershoufang/107102565510.html
# 16 高楼层边套两房南北通透强势好房 https://sh.ke.com/ershoufang/107102563952.html
# 17 地铁口 小户型，总价低  房子光线好，六楼带阁楼 https://sh.ke.com/ershoufang/107102563587.html
# 18 华骥苑飞机户型三房两卫，户型方正空间大。 https://sh.ke.com/ershoufang/107102559277.html
# 19 欣沁苑中区中高楼层精装三开间朝南两房 https://sh.ke.com/ershoufang/107102559237.html
# 20 精装大两房 南北双阳台 通风采光好 中间楼层 近地铁 https://sh.ke.com/ershoufang/107102556964.html
# 21 逸泰三居室，远眺宝龙，满足您三代同堂的梦想 https://sh.ke.com/ershoufang/107102548283.html
# 22 精装修，采光好，诚意出售，随时可看，通风好 https://sh.ke.com/ershoufang/107102546926.html
# 23 春江三月公寓二期 2室1厅 南 https://sh.ke.com/ershoufang/107102539972.html
# 24 正虹桥丨满五唯一丨电梯精装三房丨动静分离丨采光充足 https://sh.ke.com/ershoufang/107102538697.html
# 25 玫瑰湾正气小三房，诚售，看房方便，税费少 https://sh.ke.com/ershoufang/107102535344.html
# 26 中信泰富花园洋房精装修拎包入住 https://sh.ke.com/ershoufang/107102526401.html
# 27 秀景苑二期中间楼层纯边套，采光充足，视野开阔。 https://sh.ke.com/ershoufang/107102524304.html
# 28 3房2卫*明亮温馨，自住保养好。 https://sh.ke.com/ershoufang/107102522842.html
# 29 总价低，近地铁，看房方便，配套全，无遮挡，诚意出售 https://sh.ke.com/ershoufang/107102522796.html
# 30 一手动迁税费少，双南户型，景观楼层 https://sh.ke.com/ershoufang/107102522356.html
# Page 8 takes: 119.885414
# Area: qingpu Page: 9 Total Record No: 9
# 1 一手动迁税费少，双南户型，景观楼层 https://sh.ke.com/ershoufang/107102522356.html
# 2 一手动迁房无增值税，眺望佘山，景观楼层，诚心出售 https://sh.ke.com/ershoufang/107102520715.html
# 3 中间楼层 视野开阔，临水系公园（梦蝶岛）晚饭天堂 https://sh.ke.com/ershoufang/107102518197.html
# 4 南北通，采光通风好，装修拎包住 https://sh.ke.com/ershoufang/107102515507.html
# 5 房东诚意出售，南北通透，采光好，配套齐全 https://sh.ke.com/ershoufang/107102515049.html
# 6 近地铁17号线，青浦新城站  品质小区 户型方正 https://sh.ke.com/ershoufang/107102513438.html
# 7 精装两房 大阁楼带装修 采光好 满五唯一 欢迎随时咨询 https://sh.ke.com/ershoufang/107102508979.html
# 8 景观楼层+大金空调+诚心出售+看房方便+接受半年置换 https://sh.ke.com/ershoufang/107102507971.html
# 9 瑞和锦庭-东区 2室1厅 南 https://sh.ke.com/ershoufang/107102506557.html
# 10 税费少、小区品质好、出门公交车、房东诚心诚意出售 https://sh.ke.com/ershoufang/107102505644.html
# 11 高楼层中间套户型，业主诚意出售，价格合适 https://sh.ke.com/ershoufang/107102505637.html
# 12 两年精装修+中间楼层+明三开间朝南+随时可看 https://sh.ke.com/ershoufang/107102505072.html
# 13 西部花苑（二、六期） 3室2厅 南 https://sh.ke.com/ershoufang/107102504871.html
# 14 淀浦河畔精装修电梯两房，户型好，价格低，诚心卖 https://sh.ke.com/ershoufang/107102504417.html
# 15 大两房，满五唯一，近东门，拎包入住，楼层好 https://sh.ke.com/ershoufang/107102500804.html
# 16 2016商品房  满2年税费低，空调带地暖 居住舒适 https://sh.ke.com/ershoufang/107102497897.html
# 17 宜达6楼罕见超大阁楼，地铁口，一手动迁，满五唯一 https://sh.ke.com/ershoufang/107102496267.html
# 18 大虹桥花园洋房 满五唯一 买进206，钥匙房，电梯房 https://sh.ke.com/ershoufang/107102495627.html
# 19 瑞和明庭东区 2室1厅 南 https://sh.ke.com/ershoufang/107102494377.html
# 20 中间楼层，户型正气，急售，南北双阳台 https://sh.ke.com/ershoufang/107102494264.html
# 21 此房满五唯一税少、中间楼层、12年业主装修保养好 https://sh.ke.com/ershoufang/107102492044.html
# 22 大发融悦 3室2厅 南 https://sh.ke.com/ershoufang/107102490715.html
# 23 中间楼层 纯边套好房 静等您的到来 https://sh.ke.com/ershoufang/107102490079.html
# 24 河畔家苑 3室2厅 南 北 https://sh.ke.com/ershoufang/107102488368.html
# 25 原始动迁，税费少，采光好，看房方便 https://sh.ke.com/ershoufang/107102487952.html
# 26 满五唯一、近地铁、自住装修保养好 https://sh.ke.com/ershoufang/107102484966.html
# 27 原始动迁房，税费少，通透户型。诚意出售。 https://sh.ke.com/ershoufang/107102484935.html
# 28 金地天御 2室2厅 东 南 https://sh.ke.com/ershoufang/107102484009.html
# 29 大虹桥版块丨满五唯一丨随时可看 https://sh.ke.com/ershoufang/107102482864.html
# 30 店长推荐  飞机户型  真三房  诚心出售 https://sh.ke.com/ershoufang/107102481772.html
# Page 9 takes: 99.946514
# Area: qingpu Page: 10 Total Record No: 10
# 1 万科物业、虹桥品质住宅、诚意出售！ https://sh.ke.com/ershoufang/107102481100.html
# 2 南北套板式户型，厨卫全明，楼层好，位置好。 https://sh.ke.com/ershoufang/107102479123.html
# 3 正虹桥丨精装两房丨楼层位置佳丨房型正 https://sh.ke.com/ershoufang/107102477967.html
# 4 业主诚意出售，中高层，三开间朝南，户型方正 https://sh.ke.com/ershoufang/107102476538.html
# 5 有车位|产权明晰|业主诚意出售 https://sh.ke.com/ershoufang/107102473797.html
# 6 边套三房，位置楼层佳，采光通风，价格便宜 https://sh.ke.com/ershoufang/107102471646.html
# 7 地铁1000米，采光好，两房朝南+厅朝南，随时看房 https://sh.ke.com/ershoufang/107102471246.html
# 8 欧美精装修房东不常住   景观楼层，风景好 https://sh.ke.com/ershoufang/107102470857.html
# 9 我在客厅和卧室，都能俯瞰花园风光，享受阳光 https://sh.ke.com/ershoufang/107102469197.html
# 10 税费少高楼层两房朝南视野宽阔采光足配套齐出行方便 https://sh.ke.com/ershoufang/107102468432.html
# 11 幸福感爆棚的居家户型。叮咚，是你的家没错 https://sh.ke.com/ershoufang/107102468052.html
# 12 不靠马路 环境好 中间楼层大三房 配套成熟 出行方便 https://sh.ke.com/ershoufang/107102465788.html
# 13 南北通  户型方正  位置好  保养好 看房方便 https://sh.ke.com/ershoufang/107102464305.html
# 14 大发融悦，地铁口，万达茂旁，低总价高品质三房 https://sh.ke.com/ershoufang/107102461220.html
# 15 好楼层 宽视野 河景 华新两房 https://sh.ke.com/ershoufang/107102461239.html
# 16 中间套户型，高楼层，视野采光无影响 https://sh.ke.com/ershoufang/107102459311.html
# 17 此房满五年唯一，税少，毛坯可随意装修，诚心出售。 https://sh.ke.com/ershoufang/107102456824.html
# 18 二期高层观景房，业主诚意，税费各付。 https://sh.ke.com/ershoufang/107102456140.html
# 19 近地铁，装修好，户型好，看房方便，随时联系维护人 https://sh.ke.com/ershoufang/107102455303.html
# 20 三房朝南，客厅宽敞，配套齐全，产权车位 https://sh.ke.com/ershoufang/107102448559.html
# 21 业主诚意出售，中高楼层，三开间朝南，阳台落地窗！ https://sh.ke.com/ershoufang/107102448165.html
# 22 景观楼层，小区环境幽静，物业管理严格 保养相当好 https://sh.ke.com/ershoufang/107102446395.html
# 23 店长推荐  大三房  南北通 楼层好 https://sh.ke.com/ershoufang/107102444984.html
# 24 原始动迁房，交通便利，设备齐全，户型好 https://sh.ke.com/ershoufang/107102444774.html
# 25 金地天御：中宅户型，3+1房精装修，ZHONG央空调地暖 https://sh.ke.com/ershoufang/107102442237.html
# 26 采光好 空间宽敞 户型正气 配套齐全 诚意出售 https://sh.ke.com/ershoufang/107102439914.html
# 27 付款灵活 得房率高 近地铁 毓秀、佳佳幼儿园 中山医院 https://sh.ke.com/ershoufang/107102435292.html
# 28 首创一期305W自装修次新房，车位，满二税费底 https://sh.ke.com/ershoufang/107102434188.html
# 29 捷克小区4期 15年次新房 税费少 楼层位置好 房型正 https://sh.ke.com/ershoufang/107102433821.html
# 30 网红诞生地 区政府旁三开间朝南全明户型 百米农工商 https://sh.ke.com/ershoufang/107102433484.html
# Page 10 takes: 106.241221
# Area: qingpu Page: 11 Total Record No: 11
# 1 价格低，视野开阔，采光充足，配套设施齐全 https://sh.ke.com/ershoufang/107102430586.html
# 2 2014年次新电梯房，采光充足，业主诚售 https://sh.ke.com/ershoufang/107102430295.html
# 3 大虹桥版块丨满五唯一丨随时可看 https://sh.ke.com/ershoufang/107102429078.html
# 4 单价2.8万即购仁恒大四房 全明户型 满五唯一  随时看 https://sh.ke.com/ershoufang/107102428287.html
# 5 户型好，精装修，税费少，业主诚心出售 https://sh.ke.com/ershoufang/107102427695.html
# 6 崧泽华城德康雅苑 3室2厅 南 https://sh.ke.com/ershoufang/107102424906.html
# 7 热卖双南毛坯|采光很好|微风凉爽 https://sh.ke.com/ershoufang/107102423854.html
# 8 边套临河景观房  视野开阔 16年竣工 业主诚意出售 https://sh.ke.com/ershoufang/107102422433.html
# 9 地铁口1.3公里+别墅小区中间位置+车位充足看房方便 https://sh.ke.com/ershoufang/107102420684.html
# 10 旭辉玫瑰湾+临沁园湖+户型全明+房东诚心出售 https://sh.ke.com/ershoufang/107102417112.html
# 11 精装两房|满五唯一|临河景观房 https://sh.ke.com/ershoufang/107102414282.html
# 12 次新房 近地铁 视野开阔 开发商统一精装修的 https://sh.ke.com/ershoufang/107102412835.html
# 13 店长推荐 70年住宅 业主诚心出售  电梯房景观楼层 https://sh.ke.com/ershoufang/107102412720.html
# 14 泰禾红桥 3室1厅 南 https://sh.ke.com/ershoufang/107102410535.html
# 15 地铁口刚需小两房，诚意出售，店长推荐 https://sh.ke.com/ershoufang/107102410332.html
# 16 新丰公寓少有的三房户型，带装修高楼层房源 https://sh.ke.com/ershoufang/107102407636.html
# 17 业主诚心卖，新装修没有住过，拎包入住，看房随时 https://sh.ke.com/ershoufang/107102406464.html
# 18 欣乐苑好楼层两房，业主诚意出售 https://sh.ke.com/ershoufang/107102403230.html
# 19 房东诚意出售，房龄新，南北通透 https://sh.ke.com/ershoufang/107102402678.html
# 20 公园景观洋房小区、人车分流、带地暖 带车位 装修如图 https://sh.ke.com/ershoufang/107102402065.html
# 21 税费低，出行方便，小区环境好，随时签字 https://sh.ke.com/ershoufang/107102400512.html
# 22 2008年产证+全明户型中层三房+朝南一梯两户 https://sh.ke.com/ershoufang/107102399796.html
# 23 万寿大三房 中间楼层西边套 满五年唯一 近地铁17号线 https://sh.ke.com/ershoufang/107102397604.html
# 24 地铁口，次新房，配套齐全，精装交付 https://sh.ke.com/ershoufang/107102397344.html
# 25 近地铁，高楼层，精装修，配套齐全 https://sh.ke.com/ershoufang/107102397113.html
# 26 城东全明好房随时可看 此房静等有缘人 业主诚售 https://sh.ke.com/ershoufang/107102392654.html
# 27 精装修现房，近万达茂，近17号线、后面是一条河流 https://sh.ke.com/ershoufang/107102391104.html
# 28 满五唯一、小区品质好、车位多、出门交通方便、超市 https://sh.ke.com/ershoufang/107102390845.html
# 29 五浦汇A区新塘苑 2室2厅 南 https://sh.ke.com/ershoufang/107102389729.html
# 30 无抵押无户口 临河两房两卫  两房朝南 https://sh.ke.com/ershoufang/107102389046.html
# Page 11 takes: 106.563760
# Area: qingpu Page: 12 Total Record No: 12
# 1 景观楼层双南户型、精装保养好、人车分流 小区班车 https://sh.ke.com/ershoufang/107102387963.html
# 2 上海捷克住宅小区(公寓) 3室2厅 南 北 https://sh.ke.com/ershoufang/107102387925.html
# 3 价格低，户型好，位置佳，配套齐全 https://sh.ke.com/ershoufang/107102386984.html
# 4 中间套 飞机户型 房型正气  出行买菜购物都方便 https://sh.ke.com/ershoufang/107102384516.html
# 5 高楼层，精装修，近地铁，配套齐全 https://sh.ke.com/ershoufang/107102383302.html
# 6 毓秀 近地铁 精装房 配套完备  采光优秀 https://sh.ke.com/ershoufang/107102381519.html
# 7 仁恒运杰166平大平层，满五唯一，装修比较好 https://sh.ke.com/ershoufang/107102378519.html
# 8 东区纯东边套三房，中低楼层，前排空旷。 https://sh.ke.com/ershoufang/107102378222.html
# 9 万寿七区小两房小区已经改造好近世纪联华楼层好单价低 https://sh.ke.com/ershoufang/107102377475.html
# 10 随时可看、业主诚心出售、前面无楼栋遮挡 https://sh.ke.com/ershoufang/107102376749.html
# 11 房东诚心出售简单装修两房 全明正两房！！！ https://sh.ke.com/ershoufang/107102376603.html
# 12 精装修，中1央空调加地暖，采光好，看房随时 https://sh.ke.com/ershoufang/107102376348.html
# 13 一手动迁，税费少，交通方便，楼层好 https://sh.ke.com/ershoufang/107102371712.html
# 14 次新房，蛙城之上，生活配套齐全，诚意出售 https://sh.ke.com/ershoufang/107102370656.html
# 15 低价边套三房，位置楼层佳，采光通风好 https://sh.ke.com/ershoufang/107102370856.html
# 16 春江三月公寓二期 2室1厅 南 北 https://sh.ke.com/ershoufang/107102369855.html
# 17 春江三月公寓二期 2室1厅 南 https://sh.ke.com/ershoufang/107102369850.html
# 18 采光好、纯西边套、随时可看、业主诚售 https://sh.ke.com/ershoufang/107102368129.html
# 19 近地铁、出门万达茂、东渡哇城、房东诚意出售 https://sh.ke.com/ershoufang/107102367018.html
# 20 双桥公寓（一区） 2室2厅 南 https://sh.ke.com/ershoufang/107102366964.html
# 21 中间楼层 采光充足精装修大三房，地铁700米，近公园 https://sh.ke.com/ershoufang/107102366385.html
# 22 精装修 拎包入住 全明户型 楼层好 诚意出售 https://sh.ke.com/ershoufang/107102360035.html
# 23 直视青浦环城水系公园，标准洋房小区 https://sh.ke.com/ershoufang/107102355537.html
# 24 悦湖郡 2室2厅 南 https://sh.ke.com/ershoufang/107102353818.html
# 25 58弄强势两房，中高楼层，业主诚意出售 https://sh.ke.com/ershoufang/107102353051.html
# 26 新装修 中间楼层，青浦新城地铁，满五唯一，税费少 https://sh.ke.com/ershoufang/107102352729.html
# 27 “16.7”平米超大双南卧室，精装修，出门农工商 https://sh.ke.com/ershoufang/107102348197.html
# 28 青浦万达茂(住宅) 2室2厅 南 https://sh.ke.com/ershoufang/107102339912.html
# 29 中建小三房、位置好，诚意出售！ https://sh.ke.com/ershoufang/107102338991.html
# 30 大虹桥板块，花园洋房，次新房，婚房装修，看房随时， https://sh.ke.com/ershoufang/107102337620.html
# Page 12 takes: 110.046614
# Area: qingpu Page: 13 Total Record No: 13
# 1 虹桥商务区#入户花园露台#钥匙房# https://sh.ke.com/ershoufang/107102335639.html
# 2 上海捷克住宅小区(公寓) 2室2厅 南 https://sh.ke.com/ershoufang/107102335378.html
# 3 泰禾红桥 3室1厅 南 北 https://sh.ke.com/ershoufang/107102335102.html
# 4 一手动迁+无增值税+总价低+近地铁+随时可签 https://sh.ke.com/ershoufang/107102323746.html
# 5 海棠馨苑南区 2室1厅 南 https://sh.ke.com/ershoufang/107102323731.html
# 6 正虹桥丨税费少丨别墅区洋房丨人车分流|钥匙房|带电梯 https://sh.ke.com/ershoufang/107102322002.html
# 7 河景三房，厨卫全明，看房有钥匙随时能看。 https://sh.ke.com/ershoufang/107102320883.html
# 8 双南房间，客厅宽敞，超大落地窗，采光好，通风佳。 https://sh.ke.com/ershoufang/107102319428.html
# 9 此房一手动迁,税费少,纯边套,采光好 https://sh.ke.com/ershoufang/107102318877.html
# 10 2008年房龄，有阁楼 卫生间有窗户，南北通风 https://sh.ke.com/ershoufang/107102316176.html
# 11 海棠馨苑南区 2室1厅 南 https://sh.ke.com/ershoufang/107102310477.html
# 12 泰禾红桥 3室2厅 南 https://sh.ke.com/ershoufang/107102310227.html
# 13 欣乐苑边套两房，自住精装，看房方便，欢迎咨询。 https://sh.ke.com/ershoufang/107102301551.html
# 14 清河湾一期  装修清爽  一手动迁 诚意出售 https://sh.ke.com/ershoufang/107102295447.html
# 15 景观楼层，看房方便，拎包入住，看房方便 https://sh.ke.com/ershoufang/107102291060.html
# 16 业主急售价格可谈，精装地铁3房，靠宝龙广场 https://sh.ke.com/ershoufang/107102286895.html
# 17 东渡青筑 飞机户型 南北通  采光好 https://sh.ke.com/ershoufang/107102284960.html
# 18 可塑性较强，看房方便，必买好房 https://sh.ke.com/ershoufang/107102282397.html
# 19 少有洋房+露台+产证已办+物业管理好 https://sh.ke.com/ershoufang/107102282143.html
# 20 纯东边套户型，有钥匙，价格不要设限，诚心出售 https://sh.ke.com/ershoufang/107102281833.html
# 21 满二|家具家电不带走|景观楼层 https://sh.ke.com/ershoufang/107102280668.html
# 22 城东新村三区  北淀河畔  三楼精装  全明户型 https://sh.ke.com/ershoufang/107102278117.html
# 23 一手动迁，税费少！自住装修，看房方便！ https://sh.ke.com/ershoufang/107102276333.html
# 24 精装修，中间楼层，采光好，飞机户型 https://sh.ke.com/ershoufang/107102276186.html
# 25 中建锦绣天地 3室1厅 南 https://sh.ke.com/ershoufang/107102275800.html
# 26 仁恒西郊花园高区东边套，带产权车位，满二税少 https://sh.ke.com/ershoufang/107102275680.html
# 27 近地铁飞机户型带露台，电梯房1梯2户 https://sh.ke.com/ershoufang/107102268384.html
# 28 地铁口，次新房，精装交付，楼层好，视野开阔 https://sh.ke.com/ershoufang/107102267479.html
# 29 毛坯买进价354万，装修好 正对湖景 户型方正 税费少 https://sh.ke.com/ershoufang/107102266168.html
# 30 万达茂旁 大两房  一手动迁 电梯房 https://sh.ke.com/ershoufang/107102264583.html
# Page 13 takes: 112.123568
# Area: qingpu Page: 14 Total Record No: 14
# 1 隽苑 3室2厅 南 https://sh.ke.com/ershoufang/107102262651.html
# 2 高层景观房源 全明户型三房诚意出售 价格可谈拎包入住 https://sh.ke.com/ershoufang/107102258999.html
# 3 满五唯一|精装两房|南北通|视野开阔 https://sh.ke.com/ershoufang/107102256616.html
# 4 锦庭大两室，户型方正，居住舒适 https://sh.ke.com/ershoufang/107102250983.html
# 5 海棠馨苑两房精装修，业主诚意，随时看房 https://sh.ke.com/ershoufang/107102247707.html
# 6 业主诚意出售，每个房间都有窗户，双阳台，随时可看房 https://sh.ke.com/ershoufang/107102245073.html
# 7 景观房，边套两房，无增值税，看房有钥匙，诚意出售 https://sh.ke.com/ershoufang/107102242608.html
# 8 两房朝南，中高楼，视野开阔，采光好 https://sh.ke.com/ershoufang/107102241655.html
# 9 店长推荐  近万达茂  看房方便  诚心出售 https://sh.ke.com/ershoufang/107102232978.html
# 10 ：原始动迁房，交通便利，边套两房 https://sh.ke.com/ershoufang/107102232785.html
# 11 急售，汇金路旁唯一大四房，楼层好 https://sh.ke.com/ershoufang/107102231794.html
# 12 玫瑰湾正气小三房，业主诚售，看房方便，欢迎咨询 https://sh.ke.com/ershoufang/107102230401.html
# 13 南北通透双阳台，一南一北户型，采光好，视野开阔 https://sh.ke.com/ershoufang/107102229382.html
# 14 万寿中间楼层，全明户型，满五唯一 https://sh.ke.com/ershoufang/107102227417.html
# 15 万寿新村(青浦) 3室2厅 南 https://sh.ke.com/ershoufang/107102226381.html
# 16 临吾悦 大两房  诚意出售 看房方便 https://sh.ke.com/ershoufang/107102222425.html
# 17 捷克四期次新房  精装修 楼层位置好 小区品质高 https://sh.ke.com/ershoufang/107102221247.html
# 18 正虹桥丨多层电梯房丨带居住阁楼丨户型方正丨全明户型 https://sh.ke.com/ershoufang/107102220514.html
# 19 三开间朝南，户型端正，诚意出售 https://sh.ke.com/ershoufang/107102215775.html
# 20 留水园别墅 3室2厅 南 https://sh.ke.com/ershoufang/107102212590.html
# 21 上海豪都国际花园(公寓) 2室2厅 南 https://sh.ke.com/ershoufang/107102211906.html
# 22 看房方便，六楼带阁楼，诚意出售 https://sh.ke.com/ershoufang/107102209474.html
# 23 不多说 满五唯一 一手动迁 全明 双阳台三飘窗 https://sh.ke.com/ershoufang/107102209114.html
# 24 35万装修 3房 实用性强 保养好 业主诚意出售 https://sh.ke.com/ershoufang/107102208227.html
# 25 户型方正，中高楼层，采光特好。 https://sh.ke.com/ershoufang/107102207670.html
# 26 此房为大虹桥一手动迁房，无贷款，税费少，精品小三房 https://sh.ke.com/ershoufang/107102203572.html
# 27 300米范围内宝龙广场，17号地铁站，买一层加一层 https://sh.ke.com/ershoufang/107102202670.html
# 28 满五唯一，免增值税个税，楼层好采光佳，诚售随时看房 https://sh.ke.com/ershoufang/107102202124.html
# 29 南北双阳台，一南一北户型，采光好，视野开阔 https://sh.ke.com/ershoufang/107102196912.html
# 30 钥匙房|税费少|家具家电不带走|业主急售 https://sh.ke.com/ershoufang/107102195259.html
# Page 14 takes: 100.841711
# Area: qingpu Page: 15 Total Record No: 15
# 1 秀景苑经典三房，楼层好，通透采光好 https://sh.ke.com/ershoufang/107102193481.html
# 2 业主新房已定！诚意出售，次新精装修，带阁楼和阳光房 https://sh.ke.com/ershoufang/107102191523.html
# 3 电梯花园洋房 环境优质 生活舒适 https://sh.ke.com/ershoufang/107102190080.html
# 4 秀景苑唯一一套精装修三房 南北户型 拎包入住 https://sh.ke.com/ershoufang/107102189289.html
# 5 大虹桥花园洋房|户型方正|中高楼层|南北通风好|采光好 https://sh.ke.com/ershoufang/107102182809.html
# 6 新城盛世 3室2厅 南 https://sh.ke.com/ershoufang/107102180139.html
# 7 领包入住，采光好，近地铁，配套齐全，户型方正 https://sh.ke.com/ershoufang/107102178874.html
# 8 满五唯一 精装两房 采光好 视野开阔 看房随时 https://sh.ke.com/ershoufang/107102162649.html
# 9 南山雨果(公寓) 2室2厅 南 北 https://sh.ke.com/ershoufang/107102159941.html
# 10 单价低 近地铁 户型正 采光好 https://sh.ke.com/ershoufang/107102159361.html
# 11 大虹桥花园洋房 总高6楼带电梯 满五唯一 人车分流 https://sh.ke.com/ershoufang/107102151613.html
# 12 富力桃园方正两房，自带30平花园 https://sh.ke.com/ershoufang/107102148987.html
# 13 中间楼层，全明大两房，满五唯一，简装可拎包入住 https://sh.ke.com/ershoufang/107102146233.html
# 14 西部花苑二期  满五年大三房总价低 税费少 https://sh.ke.com/ershoufang/107102145303.html
# 15 地铁600米+全屋精装+中空调地暖新风系统+低密居所 https://sh.ke.com/ershoufang/107102144880.html
# 16 欣乐苑17号线环境好中间楼层边套 https://sh.ke.com/ershoufang/107102142483.html
# 17 精装两房，朝南户型，诚意出售，采光很好时间长。 https://sh.ke.com/ershoufang/107102139806.html

# %%
pudong_上海.xlsx
minhang_上海.xlsx
baoshan_上海.xlsx
xuhui_上海.xlsx
putuo_上海.xlsx
yangpu_上海.xlsx
changning_上海.xlsx
songjiang_上海.xlsx
jiading_上海.xlsx
huangpu_上海.xlsx
jingan_上海.xlsx
hongkou_上海.xlsx
qingpu_上海.xlsx
fengxian_上海.xlsx
jinshan_上海.xlsx
chongming_上海.xlsx
shanghaizhoubian_上海.xlsx

# %% [markdown]
# ### Multi-thread

# %%
from multiprocessing import Pool, Value
from itertools import repeat

def f(page_number, city_name, city_code, amap_key, dynamic_data, get_dynamic_information, verbose):
    
    start_time = time.time()
    url = 'https://' + city_code + '.ke.com/ershoufang/pg' + str(page_number)
    print('URL Start:', url)
    result = load_pages(url, city_name, amap_key, dynamic_data, get_dynamic_information, verbose)
    end_time = time.time()
    print('No: %d URL %s takes: %f' % (counter.value, url, end_time - start_time))
    counter.value += 1
    return result

def multi_thread(city_name, city_code, excel_name, amap_key, get_dynamic_information = True, start_page = 1, end_page = 100, pool_workers = 8, verbose = 0):

    # initial house_information and dynamic_data
    for key in house_information.keys():
        house_information[key] = []
    for key in dynamic_data.keys():
        dynamic_data[key] = []

    # multiprocessing
    start_time = time.time()
    pool = Pool(pool_workers)
    parameters = zip(
        range(start_page, end_page+1),
        repeat(city_name),
        repeat(city_code),
        repeat(amap_key),
        repeat(dynamic_data),
        repeat(get_dynamic_information),
        repeat(verbose))

    pool_result = pool.starmap(f, parameters)
    end_time = time.time()
    print('Total Time:', end_time-start_time)

    # save result
    temp = {}

    for key in house_information.keys():
        temp[key] = []
    for case in pool_result:
        for key in case.keys():
            temp[key].extend(case[key])

    # convert dictionary into pandas data frame
    houses = pd.DataFrame.from_dict(temp)
    houses.columns = columns
    
    # remove empty dynamic columns
    if get_dynamic_information == False:
        houses.drop(columns=dynamic_data_cn, inplace = True)
    
    # save result back to file
    houses.to_excel(excel_name, index=False)

# %%
start_page = 1
end_page = 100
pool_workers = 25
city_name = '上海'
city_code = 'sh'
excel_name = 'shanghai.xlsx'
amap_key = 'd7d06348caccd6b66b68be8e2054f778'
get_dynamic_information = False
# verbose = 0: display nothing; verbose = 1: display title & url; verbose = 2: display title & url and dynamic data cost time.
verbose = 1
# output counter
counter = Value('i', start_page)

multi_thread(city_name, city_code, excel_name, amap_key, pool_workers = pool_workers, get_dynamic_information = get_dynamic_information, start_page = start_page, end_page = end_page, verbose = verbose)

# %% [markdown]
# ### Single Thread Dynamic Field Imputation

# %%
def load_source(excel_name, dynamic_data_cn = dynamic_data_cn):
    
    source = pd.read_excel(excel_name)

    # Check and try to add missing keys
    if list(source.keys()) != columns:
        for key in dynamic_data_cn:
            source[key] = None

    # Reorder Links
    links = source['房屋链接']
    source.drop(columns=['房屋链接'], inplace = True)
    source['房屋链接'] = links

    # Change to English columns
    source.columns = house_information

    return source

# %%
# 一个人一天只能免费查50页；从那个页面断了，start设置成哪个页面。
start = 444
end = 475
city_name = '深圳'
amap_key = 'bf94ee925fa677acb320dc5a1d305740'
excel_name = city_name + '.xlsx'

source = load_source(excel_name)
for index, row in source.iloc[start: end].iterrows():
    
    start_time = time.time()

#     address = row['administrative_region'] + ' ' + row['community_name'] + ' ' + row['area_name']
    address = row['community_name']
    print(address)
    dynamic_data = load_amap_dynamic_data(address, city_name, amap_key)

    
    print('No. %d %s' % (index, row['house_link']), end= ' ')
    for key in dynamic_data.keys():
        source.at[index, key] = dynamic_data[key]
    end_time = time.time()
    print('takes: %f' % (end_time - start_time))

# %%
pd.set_option('display.max_columns', None)
source.columns = columns
source.to_excel(excel_name, index=False)
source = pd.read_excel(excel_name)
# source = load_source(excel_name)
source.iloc[380: 400]

# %% [markdown]
# ### Multi Thread Dynamic Field Imputation

# %%
def load_source(excel_name, dynamic_data_cn = dynamic_data_cn):
    
    source = pd.read_excel(excel_name)

    # Check and try to add missing keys
    if list(source.keys()) != columns:
        for key in dynamic_data_cn:
            source[key] = None

    # Reorder Links
    links = source['房屋链接']
    source.drop(columns=['房屋链接'], inplace = True)
    source['房屋链接'] = links

    # Change to English columns
    source.columns = house_information

    return source

# %%
from multiprocessing import Pool, Value
from itertools import repeat

start = 0
end = start + 50
pool_workers = 20
city_name = '北京'
excel_name = 'beijing.xlsx'
# output counter
counter = Value('i', start)
amap_key = '4d6bccdff9b15c88e224c2713e860cf0'
source = load_source(excel_name)

# Extract address
address_list = []
for index, row in source.iloc[start: end].iterrows():
    address = row['administrative_region'] + ' ' + row['community_name']  + ' ' + row['area_name']
    address_list.append(address)

def f(address, city_name, amap_key):
    start_time = time.time()
    dynamic_data = load_amap_dynamic_data(address, city_name, amap_key)
    end_time = time.time()
    print('%d / %d %s takes %f' % (counter.value, end, address, end_time - start_time))
    counter.value += 1
    return dynamic_data

# multiprocessing
start_time = time.time()
pool = Pool(pool_workers)
parameters = zip(
    address_list,
    repeat(city_name),
    repeat(amap_key))

pool_result = pool.starmap(f, parameters)
end_time = time.time()
print('Total Time:', end_time-start_time)

# assign pool result back to data frame
pool_index = 0
for index in range(start, end):
    result = pool_result[pool_index]
    pool_index += 1
    for key in result.keys():
        source.at[index, key] = result[key]

# save result to file
source.columns = columns
source.to_excel(excel_name, index=False)

# %%
# show result
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
source.iloc[start: end + 10]

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# source.iloc[2240: 2260]
source

# %% [markdown]
# ### 地铁站坐标获取

# %%
import requests
import pandas as pd

offset = 50
init = 1
city_name = '上海'

subways = {
    'name': [],
    'location': []
}

url = 'http://restapi.amap.com/v3/place/text?key=d7d06348caccd6b66b68be8e2054f778&keywords=地铁站&types=&city=' + city_name + '&children=&offset=' + str(offset) + '&page=' + str(init) + '&extensions=all'
field_page = requests.get(url)
result_json = field_page.json()
count = int(result_json['count']) // offset + init


for page in range(init, count + 1):
    
    url = 'http://restapi.amap.com/v3/place/text?key=d7d06348caccd6b66b68be8e2054f778&keywords=地铁站&types=&city=' + city_name + '&children=&offset=' + str(offset) + '&page=' + str(page) + '&extensions=all'
    print(page, url)
    field_page = requests.get(url)
    result_json = field_page.json()
    subways_json = result_json['pois']
    for subway in subways_json:
        subways['name'].append(subway['name'])
        subways['location'].append(subway['location'])


subway = pd.DataFrame.from_dict(subways)
subway['name'] = subway['name'].str.replace('\(地铁站\)', '')
subway.to_csv(city_name + 'subway.csv', index=False)
